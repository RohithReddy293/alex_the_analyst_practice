# %%
10 == 10
# Out:
# True

# %%
10 == 20
# Out:
# False

# %%
'Rohith' == 'Shyamakuri'
# Out:
# False

# %%
'Rohith' == 'Rohith'
# Out:
# True

# %%
'Rohith' < 'Shyamakuri'
# Out:
# True

# %%
for c in "Rohith": # based on the ASCII values python compares the strings
    print(c, ord(c))

for c in "Shyamakuri":
    print(c, ord(c))
# Out:
# R 82
# o 111
# h 104
# i 105
# t 116
# h 104
# S 83
# h 104
# y 121
# a 97
# m 109
# a 97
# k 107
# u 117
# r 114
# i 105

# %%
x= 'Rohith'
Y='Shyamakuri'
x!=Y
# Out:
# True

# %% [markdown]
# LOGICAL OPERATORS

# %%
(2>1) and (4>3)
# Out:
# True

# %%
(2>1) and (1>2)
# Out:
# False

# %%
('R'<'S') and (29<30)
# Out:
# True

# %%
not (1>2)
# Out:
# True

# %%
not(1<2)
# Out:
# False

# %% [markdown]
# MEMBERSHIP OPERATORS

# %%
Fav_state ='I LOVE FLORIDA'
'FLORIDA' in Fav_state
# Out:
# True

# %%
Fav_places =[ 'Melbourne','Tampa','Orlando']
'Melbourne' in Fav_places
# Out:
# True

# %%
scoops = [1,2,3,4,5]
wanted_scoops = 8

wanted_scoops in scoops
# Out:
# False

# %% [markdown]
# COMPARISON OPERATORS
# ==   # Equal
# !=   # Not equal
# >    # Greater than
# <    # Less than
# >=   # Greater than or equal to
# <=   # Less than or equal to

# %% [markdown]
# LOGICAL OPERATORS
# and   # Returns True if both conditions are True
# or    # Returns True if at least one condition is True
# not   # Reverses the result (True → False, False → True)

# %% [markdown]
# #Membership Operators
# in       # Returns True if a value is present in a sequence
# not in   # Returns True if a value is NOT present in a sequence
