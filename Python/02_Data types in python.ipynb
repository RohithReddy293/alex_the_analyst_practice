# %% [markdown]
# DATA TYPES

# %%
type(29-3)
# Out:
# int

# %%
type( 'Rohith Reddy')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
29>44
# Out:
# False

# %%
type(3+1j)
# Out:
# complex

# %%
#STRINGS
'Rohith Reddy'
# Out:
# 'Rohith Reddy'

# %%
"Rohith Reddy"
# Out:
# 'Rohith Reddy'

# %%
"""
Rohith Reddy Shyamakuri
Masters in Computer Information Systems
1239408"""
# Out:
# '\nRohith Reddy Shyamakuri\nMasters in Computer Information Systems\n1239408'

# %%
multiline="""
Rohith Reddy Shyamakuri
Masters in Computer Information Systems
1239408"""

# %%
print('Hello World')
# Out:
# Hello World

# %%
x="print"
print(x)
# Out:
# print

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(multiline)
# Out:
# Rohith Reddy Shyamakuri
# Masters in Computer Information Systems
# 1239408

# %%
"I've always wanted to go out with friends"
# Out:
# "I've always wanted to go out with friends"

# %%
type("I've always wanted to go out with friends")
# Out:
# str

# %%
a='Rohith Reddy'

# %%
print(a)
# Out:
# Rohith Reddy

# %%
print(a[:3])
# Out:
# Roh

# %%
print(a[2:5])
# Out:
# hit

# %%
print(a[3])
# Out:
# i

# %%
print(a[:-3])
# Out:
# Rohith Re

# %%
print(a[-1:-5])

# %%
print(a[-1:-5:-1])
# Out:
# ydde

# %%
#LIST
x = ['Rohith Reddy' 'Shyamakuri' 'Husnabad']#Withoutcommas,strings are glued together,1 element in the set.
y = ['Rohith Reddy','Shyamakuri','Husnabad']
#With commas → separate strings → multiple elements in the set
#Squae brackets for lists flower  brackets for sets

# %%
print(x)
# Out:
# {'Rohith ReddyShyamakuriHusnabad'}

# %%
print(y)
# Out:
# {'Rohith Reddy', 'Shyamakuri', 'Husnabad'}

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['Rohith Reddy','Shyamakuri','25',['Diploma','Btech','Masters'],'True']
# Out:
# ['Rohith Reddy', 'Shyamakuri', '25', ['Diploma', 'Btech', 'Masters'], 'True']

# %%
user_details=['Rohith Reddy','Shyamakuri']
user_details.append('Husnabad')
user_details
# Out:
# ['Rohith Reddy', 'Shyamakuri', 'Husnabad']

# %%
user_details[0]='ROHITH REDDY'
user_details
# Out:
# ['ROHITH REDDY', 'Shyamakuri', 'Husnabad']

# %%
nest_list=['Rohith Reddy','Shyamakuri','25',['Diploma','Btech','Masters'],'True']

# %%
nest_list[3][2]
# Out:
# 'Masters'

# %%
#TUPPLE
tuple_scoops = (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[0]
# Out:
# 1

# %%
tuple_scoops.append(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tuple_scoops.append(3)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# sets


daily_pints = {1,2,3}

# %%
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
daily_pints_log = {1,2,31,2,3,4,1,2,5,6,3,2}

print(daily_pints_log)
# Out:
# {1, 2, 3, 4, 5, 6, 31}

# %%
wifes_daily_pints_log = {1,3,5,7,3,24,5,7,3,2,0}

# %%
print(daily_pints_log | wifes_daily_pints_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 24, 31}

# %%
print(daily_pints_log & wifes_daily_pints_log)
# Out:
# {1, 2, 3, 5}

# %%
print(wifes_daily_pints_log - daily_pints_log )
# Out:
# {0, 24, 7}

# %%
print(wifes_daily_pints_log ^ daily_pints_log )
# Out:
# {0, 4, 6, 7, 24, 31}

# %%
# dictionaries
# Key/Value Pair

dict_cream = {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams': ['MCC','Chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'Chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values(['Alex Freberg', 5, ['MCC', 'Chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favorite ice creams'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'Alex Freberg'), ('weekly intake', 5), ('favorite ice creams', ['MCC', 'Chocolate'])])

# %%
dict_cream['name']
# Out:
# 'Alex Freberg'

# %%
dict_cream['name'] = 'Christine Freberg'

print(dict_cream)
# Out:
# {'name': 'Christine Freberg', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'Chocolate']}

# %%
dict_cream.update({'name': 'Christine Freberg', 'weekly intake': 10, 'weight': 300})

print(dict_cream)
# Out:
# {'name': 'Christine Freberg', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'Chocolate'], 'weight': 300}

# %%
del dict_cream['weight']

print(dict_cream)
# Out:
# {'name': 'Christine Freberg', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'Chocolate']}
