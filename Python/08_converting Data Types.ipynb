# %%
num_int=7
type(num_int)
# Out:
# int

# %%
num_str='7'
type(num_str)
# Out:
# str

# %%
num_sum=num_int+num_str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num_sum=num_int+num_str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num_str_con=int(num_str)
type(num_str_con)
# Out:
# int

# %%
num_sum=num_int+num_str_con
print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
list_type=[1,2,3]
type(list_type)
# Out:
# list

# %%
tuple(list_type)
# Out:
# (1, 2, 3)

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type[1,2,3,3,2,1,2,3,1]

# %%
set(list_type)
# Out:
# {1, 2, 3}

# %%
type(set(list_type))
# Out:
# set

# %%
dict_type = {'name': 'Rohith','age': 25, 'hair': 'N/A'}

type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Rohith'), ('age', 25), ('hair', 'N/A')])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'hair'])

# %%
dict_type.values()
# Out:
# dict_values(['Rohith', 25, 'N/A'])

# %%
list(dict_type.values())
# Out:
# ['Rohith', 25, 'N/A']

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
list(dict_type.keys())
# Out:
# ['name', 'age', 'hair']

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
long_str=" I Like To Sleep"
set(long_str)
# Out:
# {' ', 'I', 'L', 'S', 'T', 'e', 'i', 'k', 'l', 'o', 'p'}

# %%
list(long_str)
# Out:
# [' ',
#  'I',
#  ' ',
#  'L',
#  'i',
#  'k',
#  'e',
#  ' ',
#  'T',
#  'o',
#  ' ',
#  'S',
#  'l',
#  'e',
#  'e',
#  'p']
